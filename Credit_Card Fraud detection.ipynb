# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
data=pd.read_csv('E:\\DataSets\creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [raw]
# Time has max value as 172792 --> i.e., (172792/60*60)=47.99 --> Means it is data of two days.
# Amount has a mean value of 88 dollars. i.e., average of 88 dollars transactions has been done in these two days.

# %%
print('Number of rows : ',data.shape[0])
print('Number of columns : ',data.shape[1])
# Out:
# Number of rows :  284807
# Number of columns :  31

# %%
#We can represent this in the following way also.

print('No. of rows is {} and No. of columns is {}'.format(data.shape[0],data.shape[1]))
# Out:
# No. of rows is 284807 and No. of columns is 31

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.isnull().count()
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
# No missing data

# %%
data.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Only 492 transactions are fraudlent. i.e., data is imbalanced. Let's visualize it.

# %%
sns.countplot(data.Class.value_counts())

# %%
class_nonFraud=data.loc[data.Class==0]['Time']
class_Fraud=data.loc[data.Class==1]['Time']

# %%
class_Fraud
# Out:
# 541          406.0
# 623          472.0
# 4920        4462.0
# 6108        6986.0
# 6329        7519.0
#             ...
# 279863    169142.0
# 280143    169347.0
# 280149    169351.0
# 281144    169966.0
# 281674    170348.0
# Name: Time, Length: 492, dtype: float64

# %%
data.loc[data.Time==406.0]
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 540  406.0 -0.814054  1.538222  1.115690 -0.051667  0.092334 -1.013398
# 541  406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 542  406.0 -1.645009 -2.090799  1.592567 -1.388853  1.732899 -1.631059
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 540  0.748851 -0.124814 -0.207407  ... -0.311452 -0.627544 -0.016469
# 541 -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 542 -0.922859  0.013814  1.760777  ...  0.248155  0.415496  0.293294
#
#           V24       V25       V26       V27       V28  Amount  Class
# 540  0.363403 -0.014631  0.076914  0.467478  0.228123    1.98      0
# 541  0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 542 -0.463425 -0.405175 -0.924103  0.006586  0.018683   46.68      0
#
# [3 rows x 31 columns]

# %%
#Let's visualize the time density distribution

plt.rcParams['figure.figsize']==(100,100)
sns.distplot(class_nonFraud,kde=True,bins=200,)
sns.distplot(class_Fraud,kde=True,bins=200)
plt.legend(['Non-Fraud','Fraud'])

# %%
# We can see the decrease in the volume of transactions after 28 hours. (100000/3600=28 hours.)

# %%
# Let's visualize the amount feature.

sns.boxplot(x='Class',y='Amount',data=data)

# %%
Amount_nonFraud=data.loc[data.Class==0]['Amount']
Amount_Fraud=data.loc[data.Class==1]['Amount']

# %%
Amount_nonFraud
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 4          69.99
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284315, dtype: float64

# %%
#Let's understand this in detail.

Amount_nonFraud.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# min value is 0 and max value is 25691, but mean is 88. i.e., there are outliers. 
# Median is 22.

# %%
Amount_Fraud
# Out:
# 541         0.00
# 623       529.00
# 4920      239.93
# 6108       59.00
# 6329        1.00
#            ...
# 279863    390.00
# 280143      0.76
# 280149     77.89
# 281144    245.00
# 281674     42.53
# Name: Amount, Length: 492, dtype: float64

# %%
Amount_Fraud.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
Fraud_subset=data.loc[data.Class==1]

# %%
Fraud_subset.shape
# Out:
# (492, 31)

# %%
#Let's plot  the fraud transactions over time.

plt.scatter(Fraud_subset.Time,Fraud_subset.Amount)
plt.title('Fraud transactions over time')
plt.xlabel('Time in seconds')
plt.ylabel('Amount')
plt.show()

# %%
#Let's check the correlation

plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),cmap='rainbow')
plt.title('Pearson plot to check correlation')
# Out:
# Text(0.5, 1, 'Pearson plot to check correlation')

# %%
#Since the data is prepared using PCA, there is less significant correlation. 
# Sometimes the heavily imbalanced data will also suppress the important properties of the data.

# %%
#Let's check the density of features.


var=data.columns.values

i=0
a=data.loc[data.Class==0]
b=data.loc[data.Class==1]

plt.figure()
sns.set_style('whitegrid')
fig,ax=plt.subplots(8,4,figsize=(30,40))


for feature in var:
    i+=1
    plt.subplot(8,4,i)
    sns.kdeplot(a[feature], label='class 0',bw=0.5)
    sns.kdeplot(b[feature],label='Class 1',bw=0.5)
    plt.xlabel(feature,fontsize=20)
    #plt.tick_params(axis='both',which='major')
plt.show()

# %%
var
# Out:
# array(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9',
#        'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'Amount', 'Class'], dtype=object)

# %%
# Let's define the inputs and target variable

target=data['Class']
inputs=data.drop(['Class'],1)

# %%
inputs.shape
# Out:
# (284807, 30)

# %%
target.shape
# Out:
# (284807,)

# %%
#Splitting the data

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(inputs,target,test_size=0.25,random_state=0)

# %% [markdown]
# # Logistic Regression

# %%
# Let's use logistic regression 

from sklearn.linear_model import LogisticRegression

logreg=LogisticRegression()
logreg.fit(X_train,y_train)
# Out:
# C:\Users\SYED YUNUS AHMED\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
preds=logreg.predict(inputs)

# %%
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
logreg.score(X_train,y_train)
# Out:
# 0.9990777369443599

# %%
logreg.score(X_test,y_test)
# Out:
# 0.9990871042948232

# %%
#Let's increase the c value for stronger regularization and use L1 regularization
logreg1000=LogisticRegression(C=1000,random_state=0,penalty='l1').fit(X_train,y_train)
# Out:
# C:\Users\SYED YUNUS AHMED\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.

# %%
logreg1000.score(X_train,y_train)
# Out:
# 0.999180730788137

# %%
logreg1000.score(X_test,y_test)
# Out:
# 0.999283727985169

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(n_estimators=100,criterion='gini',random_state=0)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
rfc.score(X_train,y_train)
# Out:
# 1.0

# %%
rfc.score(X_test,y_test)
# Out:
# 0.9995505744220669

# %%
rfc.feature_importances_
# Out:
# array([0.01157308, 0.01370504, 0.01238736, 0.01737121, 0.01851194,
#        0.01606671, 0.01487914, 0.02676558, 0.01525236, 0.03382158,
#        0.09210005, 0.0716726 , 0.12547083, 0.01101958, 0.13179501,
#        0.01105167, 0.08161916, 0.13585653, 0.03135114, 0.01146198,
#        0.01242723, 0.01775767, 0.0101451 , 0.00769684, 0.00805482,
#        0.00843886, 0.01980879, 0.01102862, 0.00965198, 0.01125753])

# %%
preds=rfc.predict(X_train)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure(figsize=(10,6))
plot=sns.barplot(inputs.columns.values,rfc.feature_importances_)
plot.set_xticklabels(plot.get_xticklabels(),rotation=45)
plt.show()

# %%
y_train.shape
# Out:
# (213605,)

# %%
preds.shape
# Out:
# (213605,)

# %%
#Let's check confusion matrix

cm=pd.crosstab(y_train,preds)
cm
# Out:
# col_0       0    1
# Class
# 0      213233    0
# 1           0  372

# %% [raw]
# Looks like it is giving biased results.This can be because of the below factors :
#
# 1. Data Imbalance. (Since more transactions are non-fraud, our model may predict the non-fraud also as fraud)
# 2. Time and Amount features are not scaled.

# %%
# Let's scale the Time and Amount features.

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

scaled_time=scaler.fit_transform(data[['Time']])

# %%
scaled_time
# Out:
# array([[-1.99658302],
#        [-1.99658302],
#        [-1.99656197],
#        ...,
#        [ 1.6419735 ],
#        [ 1.6419735 ],
#        [ 1.64205773]])

# %%
scaled_time.tolist()
# Out:
# [[-1.996583023457193],
#  [-1.996583023457193],
#  [-1.9965619655334634],
#  [-1.9965619655334634],
#  [-1.9965409076097336],
#  [-1.9965409076097336],
#  [-1.996498791762274],
#  [-1.9964356179910847],
#  [-1.9964356179910847],
#  [-1.9963935021436252],
#  [-1.9963724442198953],
#  [-1.9963724442198953],
#  [-1.9963724442198953],
#  [-1.9963513862961657],
#  [-1.9963303283724358],
#  [-1.9963303283724358],
#  [-1.9963303283724358],
#  [-1.996309270448706],
#  [-1.9962882125249763],
#  [-1.9962671546012465],
#  [-1.9962460966775168],
#  [-1.996225038753787],
#  [-1.9962039808300571],
#  [-1.9962039808300571],
#  [-1.9961197491351381],
#  [-1.9961197491351381],
#  [-1.9960986912114085],
#  [-1.9960986912114085],
#  [-1.9960986912114085],
#  [-1.9960986912114085],
#  [-1.9960776332876786],
#  [-1.9960565753639488],
#  [-1.9960355174402191],
#  [-1.9960355174402191],
#  [-1.9960355174402191],
#  [-1.9960355174402191],
#  [-1.9960144595164893],
#  [-1.9960144595164893],
# ...

# %%
req_scaled_time=[item for req in scaled_time.tolist() for item in req]
scaled_time=pd.Series(req_scaled_time)

# %%
scaled_time
# Out:
# 0        -1.996583
# 1        -1.996583
# 2        -1.996562
# 3        -1.996562
# 4        -1.996541
#             ...
# 284802    1.641931
# 284803    1.641952
# 284804    1.641974
# 284805    1.641974
# 284806    1.642058
# Length: 284807, dtype: float64

# %%
#Scaling Amount variable.

scaled_amount=scaler.fit_transform(data[['Amount']])

# %%
scaled_amount
# Out:
# array([[ 0.24496426],
#        [-0.34247454],
#        [ 1.16068593],
#        ...,
#        [-0.0818393 ],
#        [-0.31324853],
#        [ 0.51435531]])

# %%
req_scaled_amount=[item for req in scaled_amount.tolist() for item in req]
scaled_amount=pd.Series(req_scaled_amount)

# %%
scaled_amount
# Out:
# 0         0.244964
# 1        -0.342475
# 2         1.160686
# 3         0.140534
# 4        -0.073403
#             ...
# 284802   -0.350151
# 284803   -0.254117
# 284804   -0.081839
# 284805   -0.313249
# 284806    0.514355
# Length: 284807, dtype: float64

# %%
# Adding scaled amounts and time to the dataframe
data=pd.concat([data,scaled_amount.rename('Scaled_amount'),scaled_time.rename('Scaled_Time')],axis=1)
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
# Let's drop Time and Amount variables

data.drop(['Time','Amount'],1,inplace=True)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
# Now let's reselect the sample to reduce the bias.

mask=np.random.rand(len(data))<0.85
train=data[mask]
test=data[~mask]
print('Train data shape is {} , Test data.shape is {}'.format(train.shape,test.shape))
# Out:
# Train data shape is (242035, 31) , Test data.shape is (42772, 31)

# %%
train.reset_index(drop=True,inplace=True)
test.reset_index(drop=True,inplace=True)

# %%
train.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4  0.260314 -0.568671 -0.371407  ... -0.559825 -0.026398 -0.371427 -0.232794
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
num_frauds=train[train.Class==1]
num_nonFrauds=train[train['Class']==0]

print('Fraud : {} and Non-Fraud : {}'.format(num_frauds.shape,num_nonFrauds.shape))
# Out:
# Fraud : (422, 31) and Non-Fraud : (241613, 31)

# %%
count=train.Class.value_counts()[1]
count
# Out:
# 422

# %%
selected=num_nonFrauds.sample(count)
selected.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 155208  0.016757  0.705670  0.146101 -0.761527  0.487170 -0.635257  0.841067
# 157088 -0.702180  0.982040  0.723349 -0.049463  0.432001 -0.080544  0.327953
# 220619 -0.358384  1.281996 -1.082115 -0.879869  0.622022 -1.795858  1.229704
# 151937 -0.610912  1.202188 -0.523633  1.061657  0.235330 -0.713988  1.334454
# 136696  0.026316  0.936745 -0.041426 -0.367177  0.653991 -0.703851  0.901469
#
#               V8        V9       V10  ...       V22       V23       V24  \
# 155208  0.028929 -0.094985 -0.210388  ... -0.620548  0.045522 -0.377912
# 157088  0.390498 -0.403726 -0.998000  ... -1.106930  0.083116  0.445663
# 220619 -0.160234 -0.456291 -0.646227  ...  0.670457 -0.257405  0.086145
# 151937  0.175162 -0.682555 -0.276203  ...  0.538301 -0.000305 -0.111552
# 136696 -0.133082  0.124586 -0.340781  ...  1.211578 -0.214959  0.743821
#
# ...

# %%
selected.reset_index(drop=True,inplace=True)

# %%
num_frauds.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 468  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 536  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4186 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 5190 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 5383  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#             V8        V9       V10  ...       V22       V23       V24  \
# 468   1.391657 -2.770089 -2.772272  ... -0.035049 -0.465211  0.320198
# 536  -0.067794 -0.270953 -0.838587  ...  0.435477  1.375966 -0.293803
# 4186 -0.399147 -0.238253 -1.525412  ... -0.932391  0.172726 -0.087330
# 5190 -0.248778 -0.247768 -4.801637  ...  0.176968 -0.436207 -0.053502
# 5383 -0.496358 -1.282858 -2.447469  ... -0.704181 -0.656805 -1.632653
#
#            V25       V26       V27       V28  Class  Scaled_amount  \
# ...

# %%
num_frauds.reset_index(drop=True,inplace=True)
num_frauds.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 2 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 3 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 4  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  1.391657 -2.770089 -2.772272  ... -0.035049 -0.465211  0.320198  0.044519
# 1 -0.067794 -0.270953 -0.838587  ...  0.435477  1.375966 -0.293803  0.279798
# 2 -0.399147 -0.238253 -1.525412  ... -0.932391  0.172726 -0.087330 -0.156114
# 3 -0.248778 -0.247768 -4.801637  ...  0.176968 -0.436207 -0.053502  0.252405
# 4 -0.496358 -1.282858 -2.447469  ... -0.704181 -0.656805 -1.632653  1.488901
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
subsample=pd.concat([selected,num_frauds])
len(subsample)
# Out:
# 844

# %%
subsample.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.016757  0.705670  0.146101 -0.761527  0.487170 -0.635257  0.841067
# 1 -0.702180  0.982040  0.723349 -0.049463  0.432001 -0.080544  0.327953
# 2 -0.358384  1.281996 -1.082115 -0.879869  0.622022 -1.795858  1.229704
# 3 -0.610912  1.202188 -0.523633  1.061657  0.235330 -0.713988  1.334454
# 4  0.026316  0.936745 -0.041426 -0.367177  0.653991 -0.703851  0.901469
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.028929 -0.094985 -0.210388  ... -0.620548  0.045522 -0.377912 -0.516966
# 1  0.390498 -0.403726 -0.998000  ... -1.106930  0.083116  0.445663 -0.313430
# 2 -0.160234 -0.456291 -0.646227  ...  0.670457 -0.257405  0.086145  0.162478
# 3  0.175162 -0.682555 -0.276203  ...  0.538301 -0.000305 -0.111552  0.059417
# 4 -0.133082  0.124586 -0.340781  ...  1.211578 -0.214959  0.743821 -0.397745
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
#Let's shuffle it

subsample=subsample.sample(frac=1).reset_index(drop=True)
subsample.head()
# Out:
#           V1         V2         V3        V4         V5        V6         V7  \
# 0 -26.457745  16.497472 -30.177317  8.904157 -17.892600 -1.227904 -31.197329
# 1   0.218810   2.715855  -5.111658  6.310661  -0.848345 -0.882446  -2.902079
# 2  -1.599457   2.607720  -2.987193  3.064156  -2.497914 -0.541103  -2.277786
# 3  -7.347955   2.397041  -7.572356  5.177819  -2.854838 -1.795239  -8.783235
# 4  -3.552173   5.426461  -3.731810  6.679062  -2.187543  2.433940  -8.748110
#
#           V8        V9        V10  ...       V22       V23       V24  \
# 0 -11.438920 -9.462573 -22.187089  ...  3.460893  0.896538  0.254836
# 1   0.939162 -3.627698  -1.873331  ...  1.037324  0.062325  0.532490
# 2   1.268166 -1.997331  -3.834775  ...  0.184087 -0.089452 -0.506000
# 3   0.437157 -3.740598  -8.332863  ...  0.543325 -0.547955 -0.503722
# 4 -12.108284 -2.856359  -5.665862  ...  2.510980  0.953933 -0.542506
#
#         V25       V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
new_count1=subsample.Class.value_counts()

# %%
sns.barplot(new_count1.index,new_count1)
plt.xlabel('0: Non-Fraud & 1 : Fraud')
plt.ylabel('count')
plt.title('Subsample')
plt.show()

# %%
corr=subsample.corr()

# %%
corr
# Out:
#                      V1        V2        V3        V4        V5        V6  \
# V1             1.000000 -0.769645  0.877507 -0.617371  0.835101  0.310036
# V2            -0.769645  1.000000 -0.845550  0.653728 -0.794014 -0.186911
# V3             0.877507 -0.845550  1.000000 -0.769479  0.851712  0.423766
# V4            -0.617371  0.653728 -0.769479  1.000000 -0.575183 -0.394445
# V5             0.835101 -0.794014  0.851712 -0.575183  1.000000  0.231089
# V6             0.310036 -0.186911  0.423766 -0.394445  0.231089  1.000000
# V7             0.881939 -0.817389  0.882620 -0.705111  0.812574  0.268594
# V8            -0.056707 -0.052092 -0.155453  0.091729 -0.186049 -0.571158
# V9             0.661102 -0.671506  0.757150 -0.782030  0.651902  0.317922
# V10            0.738422 -0.752843  0.857797 -0.796666  0.755966  0.392111
# V11           -0.530973  0.605248 -0.710357  0.792201 -0.532127 -0.452916
# V12            0.593868 -0.652077  0.760113 -0.830108  0.617017  0.461103
# ...

# %%
corr=corr[['Class']].sort_values(ascending=False,by='Class')
corr
# Out:
#                   Class
# Class          1.000000
# V4             0.711128
# V11            0.686054
# V2             0.482342
# V19            0.287441
# V20            0.166878
# V21            0.129384
# V28            0.114768
# Scaled_amount  0.077352
# V27            0.073647
# V26            0.045816
# V8             0.043035
# V22            0.027922
# V25            0.009781
# V15           -0.014324
# V23           -0.029058
# V13           -0.106183
# V24           -0.123366
# Scaled_Time   -0.181575
# V6            -0.359138
# V5            -0.378868
# V1            -0.445420
# V18           -0.474146
# V7            -0.480802
# V9            -0.550326
# V17           -0.563184
# V3            -0.566792
# V16           -0.597293
# V10           -0.623494
# V12           -0.685324
# V14           -0.742117

# %%
# We can see that v4 and v11 are having quite high vlaues (>0.5)
# and v9,v17,v3,v16,v10,v12,v14 are having high negative values.

# %%
corr[corr.Class>0.5]
# Out:
#           Class
# Class  1.000000
# V4     0.711128
# V11    0.686054

# %%
corr[corr.Class<-0.5]
# Out:
#         Class
# V9  -0.550326
# V17 -0.563184
# V3  -0.566792
# V16 -0.597293
# V10 -0.623494
# V12 -0.685324
# V14 -0.742117

# %%
tmp=subsample.copy()
tmp.head()
# Out:
#           V1         V2         V3        V4         V5        V6         V7  \
# 0 -26.457745  16.497472 -30.177317  8.904157 -17.892600 -1.227904 -31.197329
# 1   0.218810   2.715855  -5.111658  6.310661  -0.848345 -0.882446  -2.902079
# 2  -1.599457   2.607720  -2.987193  3.064156  -2.497914 -0.541103  -2.277786
# 3  -7.347955   2.397041  -7.572356  5.177819  -2.854838 -1.795239  -8.783235
# 4  -3.552173   5.426461  -3.731810  6.679062  -2.187543  2.433940  -8.748110
#
#           V8        V9        V10  ...       V22       V23       V24  \
# 0 -11.438920 -9.462573 -22.187089  ...  3.460893  0.896538  0.254836
# 1   0.939162 -3.627698  -1.873331  ...  1.037324  0.062325  0.532490
# 2   1.268166 -1.997331  -3.834775  ...  0.184087 -0.089452 -0.506000
# 3   0.437157 -3.740598  -8.332863  ...  0.543325 -0.547955 -0.503722
# 4 -12.108284 -2.856359  -5.665862  ...  2.510980  0.953933 -0.542506
#
#         V25       V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
tmp1=tmp[['V4','V11','Class']]
tmp1.head()
# Out:
#          V4       V11  Class
# 0  8.904157  4.419997      1
# 1  6.310661  1.203834      1
# 2  3.064156  1.113354      1
# 3  5.177819  5.763189      1
# 4  6.679062  2.540836      1

# %%
tmp2=tmp[['V9','V17','V3','V16','V10','V12','V14','Class']]
tmp2.head()
# Out:
#          V9        V17         V3       V16        V10        V12       V14  \
# 0 -9.462573 -12.462315 -30.177317 -6.809890 -22.187089 -10.592305 -3.926207
# 1 -3.627698  -8.152829  -5.111658 -5.241049  -1.873331  -6.172630 -3.941965
# 2 -1.997331  -5.369349  -2.987193 -3.177460  -3.834775  -4.976921 -4.549557
# 3 -3.740598 -12.503931  -7.572356 -7.586491  -8.332863  -8.707879 -9.577194
# 4 -2.856359  -3.354638  -3.731810 -1.839005  -5.665862  -6.147054 -4.328989
#
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(2,4,figsize=(20,14))

i=0
for feature in tmp2:
    i+=1
    plt.subplot(2,4,i)
    sns.boxplot(x=tmp2['Class'],y=tmp2[feature])

# %%
sns.set_style('whitegrid')
plt.figure()
fig, ax = plt.subplots(1,3,figsize=(10,4))

i=0
for feature in tmp1:
    i+=1
    plt.subplot(1,3,i)
    sns.boxplot(x=tmp1['Class'],y=tmp1[feature])

# %%
# We can see many outliers. Let's remove them.
Q1=subsample.quantile(0.25)
Q3=subsample.quantile(0.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# V1               4.152501
# V2               2.997873
# V3               5.331662
# V4               4.278490
# V5               2.375995
# V6               1.674202
# V7               3.389940
# V8               1.119796
# V9               2.510499
# V10              4.575198
# V11              3.870049
# V12              5.818221
# V13              1.471637
# V14              6.747139
# V15              1.263933
# V16              3.845589
# V17              5.595177
# V18              2.080236
# V19              1.504729
# V20              0.601423
# V21              0.841065
# V22              1.063490
# V23              0.433350
# V24              0.763342
# V25              0.691661
# V26              0.646788
# V27              0.488106
# V28              0.271222
# Class            1.000000
# Scaled_amount    0.393252
# Scaled_Time      1.814430
# dtype: float64

# %%
1.5*IQR
# Out:
# V1                6.228751
# V2                4.496810
# V3                7.997493
# V4                6.417736
# V5                3.563993
# V6                2.511304
# V7                5.084910
# V8                1.679693
# V9                3.765749
# V10               6.862797
# V11               5.805073
# V12               8.727332
# V13               2.207455
# V14              10.120709
# V15               1.895900
# V16               5.768383
# V17               8.392766
# V18               3.120354
# V19               2.257093
# V20               0.902134
# V21               1.261598
# V22               1.595235
# V23               0.650025
# V24               1.145013
# V25               1.037492
# V26               0.970182
# V27               0.732159
# V28               0.406833
# Class             1.500000
# Scaled_amount     0.589878
# Scaled_Time       2.721645
# dtype: float64

# %%
Q1-1.5*IQR
# Out:
# V1               -9.343180
# V2               -4.673332
# V3              -13.082460
# V4               -6.460595
# V5               -5.408864
# V6               -4.136587
# V7               -8.188727
# V8               -1.920478
# V9               -6.121543
# V10             -11.414312
# V11              -6.086805
# V12             -14.329569
# V13              -2.967669
# V14             -16.751321
# V15              -2.544900
# V16              -9.346825
# V17             -13.710350
# V18              -4.878112
# V19              -2.710412
# V20              -1.113726
# V21              -1.425711
# V22              -2.143818
# V23              -0.885272
# V24              -1.502090
# V25              -1.358075
# V26              -1.283839
# V27              -0.798668
# V28              -0.471379
# Class            -1.500000
# Scaled_amount    -0.936590
# Scaled_Time      -3.711380
# dtype: float64

# %%
data2=subsample[~((subsample<(Q1-2.5*IQR))| (subsample>(Q3+2.5*IQR))).any(axis=1)]

# %%
data2.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 1  0.218810  2.715855 -5.111658  6.310661 -0.848345 -0.882446 -2.902079
# 2 -1.599457  2.607720 -2.987193  3.064156 -2.497914 -0.541103 -2.277786
# 3 -7.347955  2.397041 -7.572356  5.177819 -2.854838 -1.795239 -8.783235
# 5 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767 -6.311699
# 6 -4.244068  3.480512 -1.393181 -0.529590 -1.368869 -0.744515 -0.623704
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 1  0.939162 -3.627698 -1.873331  ...  1.037324  0.062325  0.532490 -0.149145
# 2  1.268166 -1.997331 -3.834775  ...  0.184087 -0.089452 -0.506000 -0.062259
# 3  0.437157 -3.740598 -8.332863  ...  0.543325 -0.547955 -0.503722 -0.310933
# 5  3.449167 -5.416284 -7.833556  ... -0.845753  0.190674 -0.216443 -0.325033
# 6  1.689550  0.776439  1.849531  ... -0.917332  0.249670 -0.477985  0.599068
#
#         V26       V27       V28  Class  Scaled_amount  Scaled_Time
# ...

# %%
data2.shape
# Out:
# (588, 31)

# %%
len(data2)
# Out:
# 588

# %%
# Let's focus on dimensionality reduction now.

from sklearn.manifold import TSNE

X=data2.drop('Class',1)
y=data2.Class

# %%
X_tsne=TSNE(n_components=2,random_state=2).fit_transform(X.values)

# %%
X_tsne.shape
# Out:
# (588, 2)

# %%
# Our features got reduced from 31 to 2

# %%
X_tsne
# Out:
# array([[-49.219986 ,   5.2219796],
#        [-50.636436 ,  -4.0432076],
#        [-55.316616 ,  13.698337 ],
#        ...,
#        [ 19.338451 , -13.896772 ],
#        [  7.902233 ,   7.6991806],
#        [-10.754821 ,   1.6053206]], dtype=float32)

# %%
import matplotlib.patches as mpatches

f, ax = plt.subplots(figsize=(24,16))


blue_patch = mpatches.Patch(color='#0A0AFF', label='No Fraud')
red_patch = mpatches.Patch(color='#AF0000', label='Fraud')

ax.scatter(X_tsne[:,0], X_tsne[:,1], c=(y == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
ax.scatter(X_tsne[:,0], X_tsne[:,1], c=(y == 1), cmap='coolwarm', label='Fraud', linewidths=2)
ax.set_title('t-SNE', fontsize=14)

ax.grid(True)

ax.legend(handles=[blue_patch, red_patch])

# %%
# Let's split the data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.metrics import roc_auc_score,classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
import warnings
warnings.warn('ignore')
models=[]

models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('SVM', SVC()))
models.append(('RF', RandomForestClassifier(n_estimators=100)))

results=[]
names=[]

for name,model in models:
    kfold=KFold(n_splits=10,random_state=0)
    cv_results=cross_val_score(model,X_train,y_train,cv=kfold,scoring='roc_auc')
    results.append(cv_results)
    names.append(name)
    form="%s ---> %f"%(name,cv_results.mean())
    print(form)
# Out:
# LR ---> 0.979686
# KNN ---> 0.954403
# CART ---> 0.894722
# SVM ---> 0.969728
# RF ---> 0.971290

# %%
logreg=LogisticRegression().fit(X_train,y_train)

# %%
logreg.score(X_train,y_train)
# Out:
# 0.9617021276595744

# %%
logreg.score(X_test,y_test)
# Out:
# 0.9322033898305084

# %%
# Now it is giving good results.
